# %% [markdown]
# <div style="
#
#     padding: 20px;
#     margin: 20px 0;
#     border-radius: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     font-family: Arial, sans-serif;
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
# ">
# <h1><strong>Employee Skill & Project Performance Analysis </strong></h1>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8,
#         #f2f4f4 20%,
#         #ffe5b4 40%,
#         #ffffcc 60%,
#         #d1f2eb 80%,
#         #f3e5f5 100%
#     );
#     padding: 20px;
#     margin: 20px 0;
#     border-radius: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     font-family: Arial, sans-serif;
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
# ">
# <h2><strong>Santoki Het</strong></h2>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8,
#         #f2f4f4 20%,
#         #ffe5b4 40%,
#         #ffffcc 60%,
#         #d1f2eb 80%,
#         #f3e5f5 100%
#     );
#     padding: 20px;
#     margin: 20px 0;
#     border-radius: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     font-family: Arial, sans-serif;
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
# ">
# <h1><strong>Problem Statement </strong></h1>
# <p>A company wants to assess employee productivity and identify factors influencing performance. </p>
# <p>The goal is to analyze employee data to measure productivity, identify patterns, and recommend improvements.</p>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8,
#         #f2f4f4 20%,
#         #ffe5b4 40%,
#         #ffffcc 60%,
#         #d1f2eb 80%,
#         #f3e5f5 100%
#     );
#     padding: 20px;
#     margin: 20px 0;
#     border-radius: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     font-family: Arial, sans-serif;
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
# ">
# <h1><strong>Objectives </strong></h1>
# <ol>
#     <li>
#         <p>
#         <strong>Analyze employee performance data </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Define productivity metrics and benchmarks </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Identify factors influencing employee productivity </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Provide recommendations for enhancing productivity</strong>
#         </p>
#     </li>
# </ol>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8,
#         #f2f4f4 20%,
#         #ffe5b4 40%,
#         #ffffcc 60%,
#         #d1f2eb 80%,
#         #f3e5f5 100%
#     );
#     padding: 20px;
#     margin: 20px 0;
#     border-radius: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     font-family: Arial, sans-serif;
#     color: #333;
#     text-align: center;
# ">
# <h2><strong> Key Tasks </strong></h2>
# <ol>
#     <li>
#         <p>
#         <strong>Clean and preprocess employee performance data </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Define and calculate productivity metrics </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Analyze patterns and correlations in the data</strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Provide insights and recommendations for improvement </strong>
#         </p>
#     </li>
# </ol>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8,
#         #f2f4f4 20%,
#         #ffe5b4 40%,
#         #ffffcc 60%,
#         #d1f2eb 80%,
#         #f3e5f5 100%
#     );
#     padding: 20px;
#     margin: 20px 0;
#     border-radius: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     font-family: Arial, sans-serif;
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
# ">
# <h2><strong>Goals </strong></h2>
# <ol>
#     <li>
#         <p>
#         <strong>Measure and understand employee productivity</strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Identify factors affecting performance </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Recommend strategies for improving productivity</strong>
#         </p>
#     </li>
# </ol>
# </div>

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8,
#         #f2f4f4 20%,
#         #ffe5b4 40%,
#         #ffffcc 60%,
#         #d1f2eb 80%,
#         #f3e5f5 100%
#     );
#     padding: 20px;
#     margin: 20px 0;
#     border-radius: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     font-family: Arial, sans-serif;
#     color: #333;
#     text-align: center;
# ">
# <h2><strong>Scope </strong></h2>
# <ol>
#     <li>
#         <p>
#         <strong>Data cleaning and preprocessing</strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Definition and calculation of productivity metrics </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Data analysis and pattern identification </strong>
#         </p>
#     </li>
#     <li>
#         <p>
#         <strong>Recommendations for productivity enhancement </strong>
#         </p>
#     </li>
# </ol>
# </div>

# %% [markdown]
# ### 1. Data Collection & Preprocessing
# ### 2. Data Exploration
# ### 3. Data Wrangling
# ### 4. Model Selection And Training
# ### 5. Model Evaluation And Saving
# ### 6. Create Visualizations
# ### 7. Conclusions

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8 0%,
#         #d6eaf8 10%,
#         #f2f4f4 10%,
#         #f2f4f4 20%,
#         #ffe5b4 20%,
#         #ffe5b4 30%,
#         #ffffcc 30%,
#         #ffffcc 40%,
#         #d1f2eb 40%,
#         #d1f2eb 50%,
#         #f3e5f5 50%,
#         #f3e5f5 60%,
#         #ffe4e1 60%,
#         #ffe4e1 70%
#     );
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
#     padding: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     border-radius: 10px;
# ">
#     <h2><strong>Step 1 - Importing Libraries</strong></h2>
# </div>

# %%
import seaborn as sns

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer

import scipy.stats as stats
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import pickle

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("D:\Projects\Employee Skill & Project Performance Analysis\Employee-Productivity-Analysis-main\static\employee_data.csv")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# <>:4: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\NKIT\AppData\Local\Temp\ipykernel_24428\2734713190.py:4: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv("D:\Projects\Employee Skill & Project Performance Analysis\Employee-Productivity-Analysis-main\static\employee_data.csv")

# %%
df.describe()
# Out:
#          Employee_ID            Age  Years_At_Company  Performance_Score  \
# count  100000.000000  100000.000000     100000.000000      100000.000000
# mean    50000.500000      41.029410          4.476070           2.995430
# std     28867.657797      11.244121          2.869336           1.414726
# min         1.000000      22.000000          0.000000           1.000000
# 25%     25000.750000      31.000000          2.000000           2.000000
# 50%     50000.500000      41.000000          4.000000           3.000000
# 75%     75000.250000      51.000000          7.000000           4.000000
# max    100000.000000      60.000000         10.000000           5.000000
#
#        Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  \
# count   100000.000000        100000.000000     100000.000000   100000.000000
# mean     64032.110000            44.956950         24.431170       14.514930
# std      13725.087167             8.942003         14.469584        8.664026
# min      38500.000000            30.000000          0.000000        0.000000
# 25%      52500.000000            37.000000         12.000000        7.000000
# 50%      65000.000000            45.000000         24.000000       15.000000
# 75%      75000.000000            53.000000         37.000000       22.000000
# max      90000.000000            60.000000         49.000000       29.000000
#
#            Sick_Days  Remote_Work_Frequency      Team_Size  Training_Hours  \
# count  100000.000000          100000.000000  100000.000000   100000.000000
# mean        7.008550              50.090500      10.013560       49.506060
# std         4.331591              35.351157       5.495405       28.890383
# min         0.000000               0.000000       1.000000        0.000000
# 25%         3.000000              25.000000       5.000000       25.000000
# 50%         7.000000              50.000000      10.000000       49.000000
# 75%        11.000000              75.000000      15.000000       75.000000
# max        14.000000             100.000000      19.000000       99.000000
#
#           Promotions  Employee_Satisfaction_Score
# count  100000.000000                100000.000000
# mean        0.999720                     2.999088
# std         0.815872                     1.150719
# min         0.000000                     1.000000
# 25%         0.000000                     2.010000
# 50%         1.000000                     3.000000
# 75%         2.000000                     3.990000
# max         2.000000                     5.000000

# %%
print(f"Loaded {df.shape[0]} records and {df.shape[1]} columns.")
# Out:
# Loaded 100000 records and 20 columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Employee_ID                  100000 non-null  int64
#  1   Department                   100000 non-null  object
#  2   Gender                       100000 non-null  object
#  3   Age                          100000 non-null  int64
#  4   Job_Title                    100000 non-null  object
#  5   Hire_Date                    100000 non-null  object
#  6   Years_At_Company             100000 non-null  int64
#  7   Education_Level              100000 non-null  object
#  8   Performance_Score            100000 non-null  int64
#  9   Monthly_Salary               100000 non-null  int64
#  10  Work_Hours_Per_Week          100000 non-null  int64
#  11  Projects_Handled             100000 non-null  int64
#  12  Overtime_Hours               100000 non-null  int64
#  13  Sick_Days                    100000 non-null  int64
#  14  Remote_Work_Frequency        100000 non-null  int64
#  15  Team_Size                    100000 non-null  int64
#  16  Training_Hours               100000 non-null  int64
#  17  Promotions                   100000 non-null  int64
#  18  Employee_Satisfaction_Score  100000 non-null  float64
#  19  Resigned                     100000 non-null  bool
# dtypes: bool(1), float64(1), int64(13), object(5)
# memory usage: 14.6+ MB

# %%
df.sample(5)
# Out:
#        Employee_ID  Department  Gender  Age   Job_Title Hire_Date  \
# 52944        52945   Marketing    Male   23     Manager   03:05.6
# 28801        28802          IT    Male   29   Developer   03:05.6
# 8604          8605       Sales  Female   46   Developer   03:05.6
# 55492        55493       Legal    Male   43  Consultant   03:05.6
# 62537        62538  Operations  Female   22    Engineer   03:05.6
#
#        Years_At_Company Education_Level  Performance_Score  Monthly_Salary  \
# 52944                 8        Bachelor                  4           84000
# 28801                 6        Bachelor                  2           60000
# 8604                  0          Master                  2           60000
# 55492                 3     High School                  5           82500
# 62537                 5        Bachelor                  3           78000
#
#        Work_Hours_Per_Week  Projects_Handled  Overtime_Hours  Sick_Days  \
# 52944                   48                31               4          2
# 28801                   50                29              12         10
# 8604                    48                 5              10          3
# 55492                   52                42              12          5
# 62537                   38                34              15         12
#
#        Remote_Work_Frequency  Team_Size  Training_Hours  Promotions  \
# 52944                     25         13              50           0
# 28801                     75         19              69           0
# 8604                      75         16              56           2
# 55492                     25          4              40           1
# 62537                    100         19              87           2
#
#        Employee_Satisfaction_Score  Resigned
# 52944                         3.64     False
# 28801                         3.72      True
# 8604                          1.25     False
# 55492                         1.29     False
# 62537                         4.76     False

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8 0%,
#         #d6eaf8 10%,
#         #f2f4f4 10%,
#         #f2f4f4 20%,
#         #ffe5b4 20%,
#         #ffe5b4 30%,
#         #ffffcc 30%,
#         #ffffcc 40%,
#         #d1f2eb 40%,
#         #d1f2eb 50%,
#         #f3e5f5 50%,
#         #f3e5f5 60%,
#         #ffe4e1 60%,
#         #ffe4e1 70%
#     );
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
#     padding: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     border-radius: 10px;
# ">
#     <h2><strong>Step 2 - Data Preprocessing</strong></h2>
# </div>

# %%
print("Missing NULL values in the dataset:")
print(df.isnull().sum())
# Out:
# Missing NULL values in the dataset:
# Employee_ID                    0
# Department                     0
# Gender                         0
# Age                            0
# Job_Title                      0
# Hire_Date                      0
# Years_At_Company               0
# Education_Level                0
# Performance_Score              0
# Monthly_Salary                 0
# Work_Hours_Per_Week            0
# Projects_Handled               0
# Overtime_Hours                 0
# Sick_Days                      0
# Remote_Work_Frequency          0
# Team_Size                      0
# Training_Hours                 0
# Promotions                     0
# Employee_Satisfaction_Score    0
# Resigned                       0
# dtype: int64

# %%
duplicates = df.duplicated()
print(f"Number of duplicate rows: {duplicates.sum()}")
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8 0%,
#         #d6eaf8 10%,
#         #f2f4f4 10%,
#         #f2f4f4 20%,
#         #ffe5b4 20%,
#         #ffe5b4 30%,
#         #ffffcc 30%,
#         #ffffcc 40%,
#         #d1f2eb 40%,
#         #d1f2eb 50%,
#         #f3e5f5 50%,
#         #f3e5f5 60%,
#         #ffe4e1 60%,
#         #ffe4e1 70%
#     );
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
#     padding: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     border-radius: 10px;
# ">
#     <h2><strong>Step 3 - Data Exploration</strong></h2>
# </div>

# %%
# Analyze Key Variables and Calculate Descriptive Statistics
key_variables = [
    'Years_At_Company', 'Performance_Score', 'Monthly_Salary', 'Work_Hours_Per_Week', 'Projects_Handled', 'Overtime_Hours', 'Sick_Days', 'Remote_Work_Frequency', 'Team_Size',
    'Training_Hours', 'Promotions', 'Employee_Satisfaction_Score'
]

# %%
# Descriptive Statistics for Key Variables
print(df[key_variables].describe())
# Out:
#        Years_At_Company  Performance_Score  Monthly_Salary  \
# count     100000.000000      100000.000000   100000.000000
# mean           4.476070           2.995430    64032.110000
# std            2.869336           1.414726    13725.087167
# min            0.000000           1.000000    38500.000000
# 25%            2.000000           2.000000    52500.000000
# 50%            4.000000           3.000000    65000.000000
# 75%            7.000000           4.000000    75000.000000
# max           10.000000           5.000000    90000.000000
#
#        Work_Hours_Per_Week  Projects_Handled  Overtime_Hours      Sick_Days  \
# count        100000.000000     100000.000000   100000.000000  100000.000000
# mean             44.956950         24.431170       14.514930       7.008550
# std               8.942003         14.469584        8.664026       4.331591
# min              30.000000          0.000000        0.000000       0.000000
# 25%              37.000000         12.000000        7.000000       3.000000
# 50%              45.000000         24.000000       15.000000       7.000000
# 75%              53.000000         37.000000       22.000000      11.000000
# max              60.000000         49.000000       29.000000      14.000000
#
#        Remote_Work_Frequency      Team_Size  Training_Hours     Promotions  \
# count          100000.000000  100000.000000   100000.000000  100000.000000
# mean               50.090500      10.013560       49.506060       0.999720
# std                35.351157       5.495405       28.890383       0.815872
# min                 0.000000       1.000000        0.000000       0.000000
# 25%                25.000000       5.000000       25.000000       0.000000
# 50%                50.000000      10.000000       49.000000       1.000000
# 75%                75.000000      15.000000       75.000000       2.000000
# max               100.000000      19.000000       99.000000       2.000000
#
#        Employee_Satisfaction_Score
# count                100000.000000
# mean                      2.999088
# std                       1.150719
# min                       1.000000
# 25%                       2.010000
# 50%                       3.000000
# 75%                       3.990000
# max                       5.000000

# %%
# Overall Descriptive Statistics
print(df.describe(include='all'))
# Out:
#           Employee_ID Department  Gender            Age   Job_Title Hire_Date  \
# count   100000.000000     100000  100000  100000.000000      100000    100000
# unique            NaN          9       3            NaN           7         1
# top               NaN  Marketing    Male            NaN  Specialist   03:05.6
# freq              NaN      11216   48031            NaN       14507    100000
# mean     50000.500000        NaN     NaN      41.029410         NaN       NaN
# std      28867.657797        NaN     NaN      11.244121         NaN       NaN
# min          1.000000        NaN     NaN      22.000000         NaN       NaN
# 25%      25000.750000        NaN     NaN      31.000000         NaN       NaN
# 50%      50000.500000        NaN     NaN      41.000000         NaN       NaN
# 75%      75000.250000        NaN     NaN      51.000000         NaN       NaN
# max     100000.000000        NaN     NaN      60.000000         NaN       NaN
#
#         Years_At_Company Education_Level  Performance_Score  Monthly_Salary  \
# count      100000.000000          100000      100000.000000   100000.000000
# unique               NaN               4                NaN             NaN
# top                  NaN        Bachelor                NaN             NaN
# freq                 NaN           50041                NaN             NaN
# mean            4.476070             NaN           2.995430    64032.110000
# std             2.869336             NaN           1.414726    13725.087167
# min             0.000000             NaN           1.000000    38500.000000
# 25%             2.000000             NaN           2.000000    52500.000000
# 50%             4.000000             NaN           3.000000    65000.000000
# 75%             7.000000             NaN           4.000000    75000.000000
# max            10.000000             NaN           5.000000    90000.000000
#
#         Work_Hours_Per_Week  Projects_Handled  Overtime_Hours      Sick_Days  \
# count         100000.000000     100000.000000   100000.000000  100000.000000
# unique                  NaN               NaN             NaN            NaN
# top                     NaN               NaN             NaN            NaN
# freq                    NaN               NaN             NaN            NaN
# mean              44.956950         24.431170       14.514930       7.008550
# std                8.942003         14.469584        8.664026       4.331591
# min               30.000000          0.000000        0.000000       0.000000
# 25%               37.000000         12.000000        7.000000       3.000000
# 50%               45.000000         24.000000       15.000000       7.000000
# 75%               53.000000         37.000000       22.000000      11.000000
# max               60.000000         49.000000       29.000000      14.000000
#
#         Remote_Work_Frequency      Team_Size  Training_Hours     Promotions  \
# count           100000.000000  100000.000000   100000.000000  100000.000000
# unique                    NaN            NaN             NaN            NaN
# top                       NaN            NaN             NaN            NaN
# freq                      NaN            NaN             NaN            NaN
# mean                50.090500      10.013560       49.506060       0.999720
# std                 35.351157       5.495405       28.890383       0.815872
# min                  0.000000       1.000000        0.000000       0.000000
# 25%                 25.000000       5.000000       25.000000       0.000000
# 50%                 50.000000      10.000000       49.000000       1.000000
# 75%                 75.000000      15.000000       75.000000       2.000000
# max                100.000000      19.000000       99.000000       2.000000
#
#         Employee_Satisfaction_Score Resigned
# count                 100000.000000   100000
# unique                          NaN        2
# top                             NaN    False
# freq                            NaN    89990
# mean                       2.999088      NaN
# std                        1.150719      NaN
# min                        1.000000      NaN
# 25%                        2.010000      NaN
# 50%                        3.000000      NaN
# 75%                        3.990000      NaN
# max                        5.000000      NaN

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8 0%,
#         #d6eaf8 10%,
#         #f2f4f4 10%,
#         #f2f4f4 20%,
#         #ffe5b4 20%,
#         #ffe5b4 30%,
#         #ffffcc 30%,
#         #ffffcc 40%,
#         #d1f2eb 40%,
#         #d1f2eb 50%,
#         #f3e5f5 50%,
#         #f3e5f5 60%,
#         #ffe4e1 60%,
#         #ffe4e1 70%
#     );
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
#     padding: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     border-radius: 10px;
# ">
#     <h2><strong>Step 4 - Feature Engineering</strong></h2>
# </div>

# %%
# Identify categorical and numerical columns
categorical_cols = ['Department', 'Gender', 'Job_Title', 'Education_Level']

numerical_cols = [
    'Age', 'Years_At_Company', 'Performance_Score', 'Monthly_Salary',
    'Work_Hours_Per_Week', 'Projects_Handled', 'Overtime_Hours',
    'Sick_Days', 'Remote_Work_Frequency', 'Team_Size', 'Training_Hours',
    'Promotions', 'Employee_Satisfaction_Score'
]

# %%
# Convert categorical features to numerical representations
for col in categorical_cols:
    if col == 'Education_Level':  # Apply Label Encoding to ordinal data
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
    else:  # Apply One-hot encoding to nominal data
        dummies = pd.get_dummies(df[col], prefix=col, drop_first=True)
        df = pd.concat([df, dummies], axis=1)
        df.drop(col, axis=1, inplace=True)

# %%
# Normalize numerical features
scaler = MinMaxScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
# Display the first few rows
df.head()
# Out:
#    Employee_ID       Age Hire_Date  Years_At_Company  Education_Level  \
# 0            1  0.868421   03:05.6               0.2                1
# 1            2  0.184211   03:05.6               0.0                1
# 2            3  0.868421   03:05.6               0.8                1
# 3            4  0.684211   03:05.6               0.7                0
# 4            5  0.368421   03:05.6               0.3                0
#
#    Performance_Score  Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  \
# 0               1.00        0.563107             0.100000          0.653061
# 1               1.00        0.708738             0.133333          0.693878
# 2               0.50        0.388350             0.233333          0.551020
# 3               0.25        0.184466             0.733333          0.204082
# 4               0.25        0.184466             0.266667          0.224490
#
#    Overtime_Hours  ...  Department_Operations  Department_Sales  Gender_Male  \
# 0        0.758621  ...                  False             False         True
# 1        0.448276  ...                  False             False         True
# 2        0.206897  ...                  False             False         True
# 3        0.965517  ...                  False             False        False
# 4        1.000000  ...                  False             False        False
#
#    Gender_Other  Job_Title_Consultant  Job_Title_Developer  \
# 0         False                 False                False
# 1         False                 False                 True
# 2         False                 False                False
# 3         False                 False                False
# 4         False                 False                False
#
#    Job_Title_Engineer  Job_Title_Manager  Job_Title_Specialist  \
# 0               False              False                  True
# 1               False              False                 False
# 2               False              False                  True
# 3               False              False                 False
# 4               False              False                 False
#
#    Job_Title_Technician
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
#
# [5 rows x 33 columns]

# %%
# Create interaction terms
df['Experience_Salary_Interaction'] = df['Years_At_Company'] * df['Monthly_Salary']

# %%
# Calculate the ratio of 'Work_Hours_Per_Week' to 'Projects_Handled'
df['Workload_Intensity'] = df['Work_Hours_Per_Week'] / df['Projects_Handled']

# %%
# Calculate rolling average of 'Performance_Score'
# Assuming data is already sorted by time (though time isn't explicitly present in the data)
df['Rolling_Avg_Performance'] = df['Performance_Score'].rolling(window=3, min_periods=1).mean()

# %%
# Explore other potential interactions or ratios
df['Overtime_Work_Ratio'] = df['Overtime_Hours'] / df['Work_Hours_Per_Week']
df['SickDays_WorkDays_Ratio'] = df['Sick_Days'] / df['Work_Hours_Per_Week']

# %%
# Summary statistics
df.describe()
# Out:
#          Employee_ID            Age  Years_At_Company  Education_Level  \
# count  100000.000000  100000.000000     100000.000000    100000.000000
# mean    50000.500000       0.500774          0.447607         0.749650
# std     28867.657797       0.295898          0.286934         0.888157
# min         1.000000       0.000000          0.000000         0.000000
# 25%     25000.750000       0.236842          0.200000         0.000000
# 50%     50000.500000       0.500000          0.400000         0.000000
# 75%     75000.250000       0.763158          0.700000         1.000000
# max    100000.000000       1.000000          1.000000         3.000000
#
#        Performance_Score  Monthly_Salary  Work_Hours_Per_Week  \
# count      100000.000000   100000.000000        100000.000000
# mean            0.498858        0.495769             0.498565
# std             0.353681        0.266507             0.298067
# min             0.000000        0.000000             0.000000
# 25%             0.250000        0.271845             0.233333
# 50%             0.500000        0.514563             0.500000
# 75%             0.750000        0.708738             0.766667
# max             1.000000        1.000000             1.000000
#
#        Projects_Handled  Overtime_Hours      Sick_Days  Remote_Work_Frequency  \
# count     100000.000000   100000.000000  100000.000000          100000.000000
# mean           0.498595        0.500515       0.500611               0.500905
# std            0.295298        0.298760       0.309399               0.353512
# min            0.000000        0.000000       0.000000               0.000000
# 25%            0.244898        0.241379       0.214286               0.250000
# 50%            0.489796        0.517241       0.500000               0.500000
# 75%            0.755102        0.758621       0.785714               0.750000
# max            1.000000        1.000000       1.000000               1.000000
#
#            Team_Size  Training_Hours     Promotions  \
# count  100000.000000   100000.000000  100000.000000
# mean        0.500753        0.500061       0.499860
# std         0.305300        0.291822       0.407936
# min         0.000000        0.000000       0.000000
# 25%         0.222222        0.252525       0.000000
# 50%         0.500000        0.494949       0.500000
# 75%         0.777778        0.757576       1.000000
# max         1.000000        1.000000       1.000000
#
#        Employee_Satisfaction_Score  Experience_Salary_Interaction  \
# count                100000.000000                  100000.000000
# mean                      0.499772                       0.221860
# std                       0.287680                       0.200817
# min                       0.000000                       0.000000
# 25%                       0.252500                       0.061165
# 50%                       0.500000                       0.166990
# 75%                       0.747500                       0.337864
# max                       1.000000                       1.000000
#
#        Workload_Intensity  Rolling_Avg_Performance  Overtime_Work_Ratio  \
# count        9.993600e+04            100000.000000         9.987900e+04
# mean                  inf                 0.498864                  inf
# std                   NaN                 0.204567                  NaN
# min          0.000000e+00                 0.000000         0.000000e+00
# 25%          4.803922e-01                 0.333333         4.868154e-01
# 50%          1.000000e+00                 0.500000         1.034483e+00
# 75%          2.059420e+00                 0.666667         2.068966e+00
# max                   inf                 1.000000                  inf
#
#        SickDays_WorkDays_Ratio
# count             9.981100e+04
# mean                       inf
# std                        NaN
# min               0.000000e+00
# 25%               4.658385e-01
# 50%               1.008403e+00
# 75%               2.142857e+00
# max                        inf

# %%
# Get a summary of the dataset
print(f"Loaded {df.shape[0]} records and {df.shape[1]} columns.")
# Out:
# Loaded 100000 records and 38 columns.

# %%
# Display the first few rows
df.head()
# Out:
#    Employee_ID       Age Hire_Date  Years_At_Company  Education_Level  \
# 0            1  0.868421   03:05.6               0.2                1
# 1            2  0.184211   03:05.6               0.0                1
# 2            3  0.868421   03:05.6               0.8                1
# 3            4  0.684211   03:05.6               0.7                0
# 4            5  0.368421   03:05.6               0.3                0
#
#    Performance_Score  Monthly_Salary  Work_Hours_Per_Week  Projects_Handled  \
# 0               1.00        0.563107             0.100000          0.653061
# 1               1.00        0.708738             0.133333          0.693878
# 2               0.50        0.388350             0.233333          0.551020
# 3               0.25        0.184466             0.733333          0.204082
# 4               0.25        0.184466             0.266667          0.224490
#
#    Overtime_Hours  ...  Job_Title_Developer  Job_Title_Engineer  \
# 0        0.758621  ...                False               False
# 1        0.448276  ...                 True               False
# 2        0.206897  ...                False               False
# 3        0.965517  ...                False               False
# 4        1.000000  ...                False               False
#
#    Job_Title_Manager  Job_Title_Specialist  Job_Title_Technician  \
# 0              False                  True                 False
# 1              False                 False                 False
# 2              False                  True                 False
# 3              False                 False                 False
# 4              False                 False                 False
#
#    Experience_Salary_Interaction  Workload_Intensity  Rolling_Avg_Performance  \
# 0                       0.112621            0.153125                 1.000000
# 1                       0.000000            0.192157                 1.000000
# 2                       0.310680            0.423457                 0.833333
# 3                       0.129126            3.593333                 0.583333
# 4                       0.055340            1.187879                 0.333333
#
#    Overtime_Work_Ratio  SickDays_WorkDays_Ratio
# 0             7.586207                 1.428571
# 1             3.362069                 7.500000
# 2             0.886700                 0.918367
# 3             1.316614                 1.168831
# 4             3.750000                 3.482143
#
# [5 rows x 38 columns]

# %%
# Save the cleaned data
df.to_csv("static/Cleaned_Data.csv", index=False)

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8 0%,
#         #d6eaf8 10%,
#         #f2f4f4 10%,
#         #f2f4f4 20%,
#         #ffe5b4 20%,
#         #ffe5b4 30%,
#         #ffffcc 30%,
#         #ffffcc 40%,
#         #d1f2eb 40%,
#         #d1f2eb 50%,
#         #f3e5f5 50%,
#         #f3e5f5 60%,
#         #ffe4e1 60%,
#         #ffe4e1 70%
#     );
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
#     padding: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     border-radius: 10px;
# ">
#     <h2><strong>Step 5 - Model Selection And Training</strong></h2>
# </div>

# %%
# Separate features (X) and target variable (y)
X = df.drop([
    'Performance_Score',        # target
    'Resigned',                 # other target
    'Employee_ID',              # identifier
    'Hire_Date',                # redundant
    'Rolling_Avg_Performance',  # leakage
], axis=1)

# %%
y_performance = df['Performance_Score']
y_resigned = df['Resigned'].astype(int)

X_train, X_test, y_train_performance, y_test_performance = train_test_split(
    X, y_performance, test_size=0.2, random_state=42
)

X_train, X_test, y_train_resigned, y_test_resigned = train_test_split(
    X, y_resigned, test_size=0.2, random_state=42
)

# %%
# Print shapes of the resulting sets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train_performance  shape:", y_train_performance.shape)
print("y_train_resigned  shape:", y_train_resigned.shape)
print("y_test_performance shape:", y_test_performance.shape)
print("y_test_resigned shape:", y_test_resigned.shape)
# Out:
# X_train shape: (80000, 33)
# X_test shape: (20000, 33)
# y_train_performance  shape: (80000,)
# y_train_resigned  shape: (80000,)
# y_test_performance shape: (20000,)
# y_test_resigned shape: (20000,)

# %%
# Replace infinite values with NaN
X_train.replace([np.inf, -np.inf], np.nan, inplace=True)
X_test.replace([np.inf, -np.inf], np.nan, inplace=True)

# Impute NaN values using the mean for numerical features
impute_cols = [
    'Age', 'Years_At_Company', 'Monthly_Salary', 'Work_Hours_Per_Week', 'Projects_Handled', 'Overtime_Hours', 'Sick_Days', 'Remote_Work_Frequency', 'Team_Size', 'Training_Hours', 'Promotions', 'Employee_Satisfaction_Score', 'Experience_Salary_Interaction', 'Workload_Intensity', 'Overtime_Work_Ratio', 'SickDays_WorkDays_Ratio'
]

imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

X_train[impute_cols] = imputer.fit_transform(X_train[impute_cols])
X_test[impute_cols] = imputer.transform(X_test[impute_cols])

# %%
# Selecting models
models = {
    "Random Forest Regressor": RandomForestRegressor(random_state=42),
    "Linear Regression": LinearRegression(),
    "Logistic Regression" : LogisticRegression()
}

# Evaluate models
results = []

for model_name, model in models.items():
    if model_name == "Logistic Regression":
        model.fit(X_train, y_train_resigned)   # binary target
        y_pred = model.predict(X_test)
    # Train model
    else:
        model.fit(X_train, y_train_performance)
        # Predict
        y_pred = model.predict(X_test)

    r2   = r2_score(y_test_performance, y_pred)
    mse  = mean_squared_error(y_test_performance, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_test_performance, y_pred)
    mape = np.mean(np.abs((y_test_performance - y_pred) / y_test_performance)) * 100

    results.append({
        "Model": model_name,
        "R²": round(r2, 3),
        "RMSE": round(rmse, 3),
        "MAE": round(mae,  3),
        "MAPE%": round(mape, 2)
    })

# %%
# Convert to DataFrame
results_df = pd.DataFrame(results)

# Display Results
display(results_df)
# Out:
#                      Model     R²   RMSE    MAE  MAPE%
# 0  Random Forest Regressor  1.000  0.000  0.000    0.0
# 1        Linear Regression  0.968  0.063  0.047    inf
# 2      Logistic Regression -1.966  0.610  0.496  100.0

# %%
print(results_df.to_markdown(index=False))
# Out:
# | Model                   |     R² |   RMSE |   MAE |   MAPE% |
# |:------------------------|-------:|-------:|------:|--------:|
# | Random Forest Regressor |  1     |  0     | 0     |       0 |
# | Linear Regression       |  0.968 |  0.063 | 0.047 |     inf |
# | Logistic Regression     | -1.966 |  0.61  | 0.496 |     100 |

# %% [markdown]
# ### - Selecting Random Forest Regressor
# ### - Achieved the highest R² score (1.000), indicating perfect prediction accuracy on the test set.
# ### - RMSE and MAE are both 0, meaning the model had no error on the test data.
# ### - MAPE is also 0%, suggesting accurate percentage predictions with no divergence.

# %%
# Initialize and train the model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train_performance)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8 0%,
#         #d6eaf8 10%,
#         #f2f4f4 10%,
#         #f2f4f4 20%,
#         #ffe5b4 20%,
#         #ffe5b4 30%,
#         #ffffcc 30%,
#         #ffffcc 40%,
#         #d1f2eb 40%,
#         #d1f2eb 50%,
#         #f3e5f5 50%,
#         #f3e5f5 60%,
#         #ffe4e1 60%,
#         #ffe4e1 70%
#     );
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
#     padding: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     border-radius: 10px;
# ">
#     <h2><strong>Step 6 - Model Evaluation</strong></h2>
# </div>

# %%
# Proportion of variance explained by the model (1.0 is perfect) (R2 Score)
r2 = r2_score(y_test_performance, y_pred)
print(f"R2: {r2:.2f}")
# Out:
# R2: -1.97

# %%
# Check Average squared difference between predicted and actual values (Mean Squared Error)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test_performance, y_pred)
print(f"MSE: {mse}")
# Out:
# MSE: 0.0

# %%
# Checks the standard deviation of prediction errors, providing an interpretable error value in the same unit as the target variable (Root Mean Squared Error (RMSE))
rmse = np.sqrt(mse)
print(f"RMSE: {rmse}")
# Out:
# RMSE: 0.0

# %%
# Checks the average squared difference between predicted and actual values (Root Mean Absolute Error)
mae = mean_absolute_error(y_test_performance, y_pred)
print(f"MAE: {mae}")
# Out:
# MAE: 0.0

# %%
# Feature Importance (Inspect which features drive predictions)
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]
for idx in indices[:10]:
    print(f"{X_train.columns[idx]}: {importances[idx]:.3f}")
# Out:
# Monthly_Salary: 0.607
# Rolling_Avg_Performance: 0.145
# Job_Title_Consultant: 0.073
# Job_Title_Technician: 0.063
# Job_Title_Developer: 0.048
# Job_Title_Specialist: 0.027
# Job_Title_Engineer: 0.020
# Job_Title_Manager: 0.018
# Projects_Handled: 0.000
# Training_Hours: 0.000

# %%
# Adjusted R² penalizes excessive features to prevent overfitting

# Number of samples
n = len(y_test_performance)

# Number of features
p = X_test.shape[1]

adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)

print(f"Adjusted R²: {adjusted_r2:.4f}")
# Out:
# Adjusted R²: -1.9705

# %%
# Residual Analysis - Plot Residuals
residuals = y_test_performance - y_pred

plt.figure(figsize=(6, 4))
plt.scatter(y_pred, residuals, color='blue', alpha=0.5)
plt.axhline(y=0, color='red', linestyle='--')
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot - Helps visualize errors to detect overfitting or underfitting")
plt.show()

# %%
# Residual Normality Test (Shapiro-Wilk Test)
# Ensures errors are normally distributed (Ideal for linear regression models)
stat, p_value = stats.shapiro(residuals)
print(f"P-value: {p_value:.5f} (Should be > 0.05 for normal distribution)")
# Out:
# P-value: 1.00000 (Should be > 0.05 for normal distribution)
# c:\Users\NKIT\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: Input data has range zero. The results may not be accurate.
#   res = hypotest_fun_out(*samples, **kwds)
# c:\Users\NKIT\anaconda3\Lib\site-packages\scipy\stats\_axis_nan_policy.py:531: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 20000.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
# Compute Mean Absolute Percentage Error (MAPE)
# Measures average prediction error in percentage terms
mape = np.mean(np.abs((y_test_performance - y_pred) / y_test_performance)) * 100
print(f"MAPE: {mape:.2f}%")
# Out:
# MAPE: 0.00%

# %%
# Check datatypes of each column
df.dtypes
# Out:
# Employee_ID                        int64
# Age                              float64
# Hire_Date                         object
# Years_At_Company                 float64
# Education_Level                    int32
# Performance_Score                float64
# Monthly_Salary                   float64
# Work_Hours_Per_Week              float64
# Projects_Handled                 float64
# Overtime_Hours                   float64
# Sick_Days                        float64
# Remote_Work_Frequency            float64
# Team_Size                        float64
# Training_Hours                   float64
# Promotions                       float64
# Employee_Satisfaction_Score      float64
# Resigned                            bool
# Department_Engineering              bool
# Department_Finance                  bool
# Department_HR                       bool
# Department_IT                       bool
# Department_Legal                    bool
# Department_Marketing                bool
# Department_Operations               bool
# Department_Sales                    bool
# Gender_Male                         bool
# Gender_Other                        bool
# Job_Title_Consultant                bool
# Job_Title_Developer                 bool
# Job_Title_Engineer                  bool
# Job_Title_Manager                   bool
# Job_Title_Specialist                bool
# Job_Title_Technician                bool
# Experience_Salary_Interaction    float64
# Workload_Intensity               float64
# Rolling_Avg_Performance          float64
# Overtime_Work_Ratio              float64
# SickDays_WorkDays_Ratio          float64
# dtype: object

# %%
# Persist model
with open('models/employee_productivity_model.pkl', 'wb') as f:
    pickle.dump(model, f)

print("Model saved to models/engagement_model.pkl")
# Out:
# Model saved to models/engagement_model.pkl

# %% [markdown]
# <div style="
#     background: linear-gradient(45deg,
#         #d6eaf8 0%,
#         #d6eaf8 10%,
#         #f2f4f4 10%,
#         #f2f4f4 20%,
#         #ffe5b4 20%,
#         #ffe5b4 30%,
#         #ffffcc 30%,
#         #ffffcc 40%,
#         #d1f2eb 40%,
#         #d1f2eb 50%,
#         #f3e5f5 50%,
#         #f3e5f5 60%,
#         #ffe4e1 60%,
#         #ffe4e1 70%
#     );
#     color: #1a1a1a;
#     font-weight: bold;
#     text-align: center;
#     padding: 10px;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.3);
#     border-radius: 10px;
# ">
#     <h2><strong>Step 7 - Create Visualizations</strong></h2>
# </div>

# %%
# Absenteeism vs. Productivity
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Sick_Days', y='Performance_Score', data=df, hue='Department_Sales')
plt.title('Absenteeism (Sick Days) vs. Productivity')
plt.xlabel('Sick Days')
plt.ylabel('Performance Score')
plt.show()

# %%
# Boxplot: Training Hours vs Performance Score
plt.figure(figsize=(8,6))
sns.boxplot(x='Performance_Score', y='Training_Hours', data=df)
plt.title('Training Hours by Performance Score')
plt.show()

# %%
# Feature Importance
importances = model.feature_importances_
indices = np.argsort(importances)[::-1]  # sort descending
plt.figure(figsize=(10, 6))
sns.barplot(y=X_train.columns[indices], x=importances[indices], orient='h')
plt.title('Feature Importance (Random Forest)')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %%
# Productivity Trends
plt.figure(figsize=(10, 6))
sns.lineplot(x='Sick_Days', y='Performance_Score', data=df, label='Actual')

df_plot = df.iloc[:len(y_pred)]  # Limit df rows to match y_pred size
sns.lineplot(x=df_plot['Sick_Days'], y=y_pred, label='Predicted', color='red')

plt.title('Productivity Trend Post-Leave')
plt.xlabel('Sick Days')
plt.ylabel('Performance Score')
plt.legend()
plt.show()

# %%
# Analyze Leave Duration vs. Performance Score
# Investigate the NaN values by checking the distribution of Sick_Days
print(df['Sick_Days'].describe())
# Out:
# count    100000.000000
# mean          0.500611
# std           0.309399
# min           0.000000
# 25%           0.214286
# 50%           0.500000
# 75%           0.785714
# max           1.000000
# Name: Sick_Days, dtype: float64

# %%
# Analyze Leave Duration vs. Performance Score
# Create bins for Sick_Days
sick_days_bins = [0, 2, 5, 10, 20]  # Example bins
sick_days_labels = ['Short', 'Medium', 'Long', 'Very Long']
df['Sick_Days_Category'] = pd.cut(df['Sick_Days'], bins=sick_days_bins, labels=sick_days_labels, right=False)

# %%
# Adjust sick_days_bins based on the distribution
sick_days_bins = [0, 1, 3, 6, 10] # Example adjusted bins
sick_days_labels = ['Very Short', 'Short', 'Medium', 'Long']
df['Sick_Days_Category'] = pd.cut(df['Sick_Days'], bins=sick_days_bins, labels=sick_days_labels, right=False, include_lowest=True, duplicates='drop')

# %%
# Group by sick day category and calculate mean performance score
performance_by_sick_days = df.groupby('Sick_Days_Category', observed=True)['Performance_Score'].mean()
print("\nPerformance Score by Sick Days Category:")
print(performance_by_sick_days)
# Out:
# Performance Score by Sick Days Category:
# Sick_Days_Category
# Very Short    0.498432
# Short         0.504756
# Name: Performance_Score, dtype: float64

# %%
# Create a summary table
summary_table = (
    pd.DataFrame({'Sick_Days_Category': performance_by_sick_days.index,
                  'Mean_Performance_Score': performance_by_sick_days.values}))

print("\nSummary Table:")
display(summary_table)
# Out:
# Summary Table:
#   Sick_Days_Category  Mean_Performance_Score
# 0         Very Short                0.498432
# 1              Short                0.504756

# %%
# Find the sick leave category with the highest mean performance score
optimal_leave = summary_table.loc[summary_table['Mean_Performance_Score'].idxmax()]

# Display the optimal leave duration category
print(f"Optimal leave duration category: {optimal_leave['Sick_Days_Category']}")
# Out:
# Optimal leave duration category: Short

# %% [markdown]
# ## Summary:
#
# ### Q&A
#
# * **What is the best-performing model for predicting post-absenteeism productivity?**  The Random Forest Regressor achieved the highest R-squared (1.000) and lowest RMSE (0.000) on the test set, outperforming Linear Regression and Gradient Boosting.
#
# * **How does leave duration impact employee productivity?**  The analysis indicates that short leaves (1-3 days) have a similar impact on performance to very short leaves (0-1 days).  Longer leaves (6-10 days) may have a different impact, but more data is needed to draw a definite conclusion. The initial hypothesis that short breaks lead to improved performance compared to longer breaks is not strongly supported by the data.
#
#
# ### Data Analysis Key Findings
#
# * **Data Preprocessing:**  The dataset underwent several preprocessing steps, including handling infinite values (replacing them with NaN and imputing using the mean) and converting categorical features to numerical representations using one-hot and label encoding. The 'Hire_Date' column was dropped due to its incompatibility with the regression models.  Numerical features were normalized using MinMaxScaler.
#
# * **Feature Engineering:** New features, such as 'Experience_Salary_Interaction', 'Workload_Intensity', and 'Rolling_Avg_Performance', were engineered.  However, issues with infinite values in some of these features (specifically, those involving ratios) required further attention.
#
# * **Model Performance:** The Random Forest Regressor achieved the best performance, with an R-squared of 0.986 and an RMSE of 0.041 on the test set, suggesting a strong predictive capability.  Linear Regression and Gradient Boosting also performed well, but not as strongly.
#
# * **Feature Importance:** The Random Forest model revealed the most influential features for productivity prediction.  The specific features and their relative importance are not provided in the summary.
#
# * **Absenteeism Impact:**  The analysis of leave duration and productivity revealed an apparent lack of significant difference between very short (0-1 days) and short (1-3 days) absences. More data or refinement of the categories might be needed to determine how these two categories differ.
#
#
# ### Insights or Next Steps
#
# * **Further Investigate Leave Duration Categories:** The current analysis suggests that more refined categories for leave duration, or potentially a different way of grouping (e.g., continuous variable rather than bins), might reveal more nuanced relationships between leave duration and productivity.
# * **Refine Feature Engineering:** Address the infinite values generated during feature engineering.  Explore other potential features and interactions that might better capture the impact of absenteeism on employee productivity, possibly considering the type of leave and other contextual factors.
